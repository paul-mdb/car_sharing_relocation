# %% [markdown]
# # Downloading and processing the data for one district
#
# https://www.elastic.co/guide/en/elasticsearch/reference/current/docs-update-by-query.html to update and clean the data ?

# %%
zipcode = 75015

# %% [markdown]
# ### Imports & connection to Elasticsearch

# %%
from elasticsearch import Elasticsearch
from ssl import create_default_context
import pandas as pd
import numpy as np
import sys
import datetime

es = Elasticsearch("https://elastic:cLAZZSf96XI5AR247XYDl9W5@efa8ba28126d463b873bf67c74f49e0f.eu-west-1.aws.found.io:9243")
# es.info()

# %% [markdown]
# ### Change maximum size setting
# By default the query returns the first 10,000 hits

# %%
es.indices.put_settings(
    index="carshare_car_history",
    body={
        "index.max_result_window": 500000
    }

)
# Out:
# {'acknowledged': True}

# %% [markdown]
# ## Query
# Fetch all data in 75015 district. This should be repeated for each zipcode.

# %%
result = es.search(
  index="carshare_car_history",
  body = {
  "size": 200000,
  "query": {

      "bool": {
        "must": {
          "match_all": {}
        },
        "filter": [
    {
    "geo_shape": {
      "ignore_unmapped": "true",
      "location": {
        "relation": "INTERSECTS",
        "shape": {
          "coordinates": [
            [
              [
                1.87411, 49.08001
              ],
              [
                1.87411,
                48.64617
              ],
              [
                2.72473,
                48.64617
              ],
              [
                2.72473,
                49.08001
              ],
              [
                1.87411,
                49.08001
              ]
            ]
          ],
          "type": "Polygon"
        }
      }
    }
  },
  
  {
      "match_phrase": {
        "brand": "Zity"
      }    
  },
  
{
      "match_phrase": {
        "zipcode": zipcode
      }    
  },

  {
      "range": { 
        "last_update": {
          "gte": "2020-01-01T00:00:00",
          "lte": "2022-05-09T00:00:00" # fetch data until May 10th, 2022
          }
        }}
        ]
  
    }

  }
},
request_timeout=30 # default timeout is 10sec
 
)
result
# Out:
# {'took': 3474,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '8247c5c1-59f9-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357493.68711494,
#      'battery': 20.0,
#      'mileage': 2170.0,
#      'location': '48.8342,2.3084',
#      '@timestamp': '2022-01-12T23:40:44.175Z',
#      'end_zipcode': '75015',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-10T20:51:13.600Z',
#      '@version': '1',
#      'time_since_last_charge': 76.428781602,
#      'start_charging_date': None,
#      'end_address': '4 Villa Croix-Nivert, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-10T20:41:13.613Z',
#      'brand': 'Zity',
#      'duration': 9.999588643,
#      'end_location': '48.8461,2.2995',
#      'car_model': 'Spring',
#      'pk_field': '8247c5c1-59f9-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 357.687114935,
#      'group_id': 'Zity',
#      'end__date': '2021-12-10T20:51:13.600Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FZ-162-RF',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 19.0,
#      'time_since_last_mission': 0,
#      'id': '8247c5c1-59f9-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '33 Rue Labrouste, 75015 Paris, France',
#      'distance': 2.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '824855d1-65bc-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357852.91307142,
#      'battery': 33.0,
#      'mileage': 1792.0,
#      'location': '48.8510,2.2844',
#      '@timestamp': '2022-01-12T23:40:44.175Z',
#      'end_zipcode': '75015',
#      'week_day': 'Saturday',
#      'status': 'FREE',
#      'last_update': '2021-12-26T14:39:03.447Z',
#      '@version': '1',
#      'time_since_last_charge': 71.789738088,
#      'start_charging_date': None,
#      'end_address': '51 Quai de Grenelle, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-25T19:54:47.057Z',
#      'brand': 'Zity',
#      'duration': 1124.272802538,
#      'end_location': '48.8508,2.2844',
#      'car_model': 'Spring',
#      'pk_field': '824855d1-65bc-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 220.253071421,
#      'group_id': 'Zity',
#      'end__date': '2021-12-26T14:39:03.447Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-996-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 33.0,
#      'time_since_last_mission': 0,
#      'id': '824855d1-65bc-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': 'Quai de Grenelle, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '824dcf2e-5dd7-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5757.359746241,
#      'battery': 86.0,
#      'mileage': 11737.0,
#      'location': '48.8299,2.2682',
#      '@timestamp': '2022-01-12T23:40:44.275Z',
#      'end_zipcode': '75015',
#      'week_day': 'Wednesday',
#      'status': 'BOOKED_PARKED',
#      'last_update': '2021-12-15T18:51:54.027Z',
#      '@version': '1',
#      'time_since_last_charge': 36.504808185,
#      'start_charging_date': None,
#      'end_address': 'Parc Suzanne Lenglen, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-15T18:47:54.310Z',
#      'brand': 'Zity',
#      'duration': 3.994546605,
#      'end_location': '48.8299,2.2682',
#      'car_model': 'Renault ZOE',
#      'pk_field': '824dcf2e-5dd7-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 475.798419296,
#      'group_id': 'Zity',
#      'end__date': '2021-12-15T18:51:54.027Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-627-JR',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 86.0,
#      'time_since_last_mission': 0,
#      'id': '824dcf2e-5dd7-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': 'Parc Suzanne Lenglen, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82654e00-666e-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357874.15153876,
#      'battery': 22.0,
#      'mileage': 1069.0,
#      'location': '48.8471,2.2851',
#      '@timestamp': '2022-01-12T23:40:47.180Z',
#      'end_zipcode': '75016',
#      'week_day': 'Sunday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-26T17:25:06.463Z',
#      '@version': '1',
#      'time_since_last_charge': 42.63403876,
#      'start_charging_date': None,
#      'end_address': '73 Boulevard de Beauséjour, 75016 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-26T17:09:05.540Z',
#      'brand': 'Zity',
#      'duration': 16.015234888,
#      'end_location': '48.8559,2.2650',
#      'car_model': 'Spring',
#      'pk_field': '82654e00-666e-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 412.762649871,
#      'group_id': 'Zity',
#      'end__date': '2021-12-26T17:25:06.463Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-972-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 20.0,
#      'time_since_last_mission': 0,
#      'id': '82654e00-666e-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '47 Rue Linois, 75015 Paris, France',
#      'distance': 3.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '826df4f3-5cea-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5746.824790224,
#      'battery': 96.0,
#      'mileage': 15972.0,
#      'location': '48.8386,2.2721',
#      '@timestamp': '2022-01-12T23:40:51.100Z',
#      'end_zipcode': '75015',
#      'week_day': 'Tuesday',
#      'status': 'FREE',
#      'last_update': '2021-12-14T14:41:30.530Z',
#      '@version': '1',
#      'time_since_last_charge': 15.837326335,
#      'start_charging_date': None,
#      'end_address': '24 Rue du Professeur Florian Delbarre, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-14T14:31:30.373Z',
#      'brand': 'Zity',
#      'duration': 10.00244949,
#      'end_location': '48.8386,2.2721',
#      'car_model': 'Renault ZOE',
#      'pk_field': '826df4f3-5cea-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 375.525104112,
#      'group_id': 'Maintenance',
#      'end__date': '2021-12-14T14:41:30.530Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-726-JR',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 96.0,
#      'time_since_last_mission': 0,
#      'id': '826df4f3-5cea-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '24 Rue du Professeur Florian Delbarre, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82926944-6469-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357812.46969734,
#      'battery': 7.0,
#      'mileage': 3227.0,
#      'location': '48.8421,2.3226',
#      '@timestamp': '2022-01-12T23:40:56.880Z',
#      'end_zipcode': '75013',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-24T03:58:11.093Z',
#      '@version': '1',
#      'time_since_last_charge': 199.204975122,
#      'start_charging_date': None,
#      'end_address': '52 Rue du Moulinet, 75013 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T03:28:10.910Z',
#      'brand': 'Zity',
#      'duration': 30.00288525,
#      'end_location': '48.8268,2.3525',
#      'car_model': 'Spring',
#      'pk_field': '82926944-6469-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 15.608030677,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T03:58:11.093Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FZ-557-RF',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 3.0,
#      'time_since_last_mission': 0,
#      'id': '82926944-6469-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '24 Rue du Départ, 75015 Paris, France',
#      'distance': 5.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82a988ee-566d-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357385.35820043,
#      'battery': 70.0,
#      'mileage': 16233.0,
#      'location': '48.8282,2.2972',
#      '@timestamp': '2022-01-12T23:40:59.491Z',
#      'end_zipcode': '75015',
#      'week_day': 'Monday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-06T09:31:30.550Z',
#      '@version': '1',
#      'time_since_last_charge': 22.302922652,
#      'start_charging_date': None,
#      'end_address': '31 Avenue de la Porte Brancion, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-06T08:21:29.520Z',
#      'brand': 'Zity',
#      'duration': 70.01665248,
#      'end_location': '48.8264,2.3007',
#      'car_model': 'Renault ZOE',
#      'pk_field': '82a988ee-566d-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 287.45320043,
#      'group_id': 'Zity',
#      'end__date': '2021-12-06T09:31:30.550Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FA-389-MN',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 50.0,
#      'time_since_last_mission': 0,
#      'id': '82a988ee-566d-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '52 Avenue Albert Bartholomé, 75015 Paris, France',
#      'distance': 42.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82abe13c-64e9-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5922.971021682,
#      'battery': 23.0,
#      'mileage': 15594.0,
#      'location': '48.8456,2.2882',
#      '@timestamp': '2022-01-12T23:40:59.709Z',
#      'end_zipcode': '75015',
#      'week_day': 'Friday',
#      'status': 'FREE',
#      'last_update': '2021-12-24T23:14:27.857Z',
#      '@version': '1',
#      'time_since_last_charge': 111.900402237,
#      'start_charging_date': None,
#      'end_address': '60 Rue des Entrepreneurs, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T18:44:24.447Z',
#      'brand': 'Zity',
#      'duration': 220.051091633,
#      'end_location': '48.8456,2.2882',
#      'car_model': 'Renault ZOE',
#      'pk_field': '82abe13c-64e9-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 499.74012446,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T22:24:27.533Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FC-678-BK',
#      'time_since_last_free': 27653500000,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 23.0,
#      'time_since_last_mission': 0,
#      'id': '82abe13c-64e9-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '60 Rue des Entrepreneurs, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82abe158-64e9-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357827.7403032,
#      'battery': 42.0,
#      'mileage': 3157.0,
#      'location': '48.8378,2.3075',
#      '@timestamp': '2022-01-12T23:40:59.709Z',
#      'end_zipcode': '75003',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-24T19:24:25.907Z',
#      '@version': '1',
#      'time_since_last_charge': 89.865580973,
#      'start_charging_date': None,
#      'end_address': '2 Rue du Béarn, 75003 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T18:44:25.090Z',
#      'brand': 'Zity',
#      'duration': 40.013334408,
#      'end_location': '48.8564,2.3659',
#      'car_model': 'Spring',
#      'pk_field': '82abe158-64e9-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 264.53224764,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T19:24:25.907Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FZ-972-RF',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 35.0,
#      'time_since_last_mission': 0,
#      'id': '82abe158-64e9-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '44 Rue de la Procession, 75015 Paris, France',
#      'distance': 9.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82abe15d-64e9-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357827.74033097,
#      'battery': 66.0,
#      'mileage': 1422.0,
#      'location': '48.8414,2.2848',
#      '@timestamp': '2022-01-12T23:40:59.709Z',
#      'end_zipcode': '75017',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-24T19:18:24.993Z',
#      '@version': '1',
#      'time_since_last_charge': 44.956719859,
#      'start_charging_date': None,
#      'end_address': '261 Boulevard Pereire, 75017 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T18:44:25.190Z',
#      'brand': 'Zity',
#      'duration': 33.996300268,
#      'end_location': '48.8786,2.2857',
#      'car_model': 'Spring',
#      'pk_field': '82abe15d-64e9-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 196.845886526,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T19:18:24.993Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-025-JY',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 60.0,
#      'time_since_last_mission': 0,
#      'id': '82abe15d-64e9-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '134 Rue de Lourmel, 75015 Paris, France',
#      'distance': 6.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82abe160-64e9-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357827.74035737,
#      'battery': 38.0,
#      'mileage': 1892.0,
#      'location': '48.8522,2.2915',
#      '@timestamp': '2022-01-12T23:40:59.709Z',
#      'end_zipcode': '92190',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-24T19:10:24.797Z',
#      '@version': '1',
#      'time_since_last_charge': 133.304525404,
#      'start_charging_date': None,
#      'end_address': '6 Rue de Paris, 92190 Meudon, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T18:44:25.290Z',
#      'brand': 'Zity',
#      'duration': 25.991681383,
#      'end_location': '48.8170,2.2479',
#      'car_model': 'Spring',
#      'pk_field': '82abe160-64e9-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 523.740358737,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T19:10:24.797Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-805-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 32.0,
#      'time_since_last_mission': 0,
#      'id': '82abe160-64e9-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '35 Boulevard de Grenelle, 75015 Paris, France',
#      'distance': 8.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82abe166-64e9-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357827.74038652,
#      'battery': 37.0,
#      'mileage': 1342.0,
#      'location': '48.8530,2.2972',
#      '@timestamp': '2022-01-12T23:40:59.709Z',
#      'end_zipcode': '75116',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-24T19:18:25.043Z',
#      '@version': '1',
#      'time_since_last_charge': 110.328442073,
#      'start_charging_date': None,
#      'end_address': '16 Rue du Général Appert, 75116 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T18:44:25.390Z',
#      'brand': 'Zity',
#      'duration': 33.993933883,
#      'end_location': '48.8690,2.2756',
#      'car_model': 'Spring',
#      'pk_field': '82abe166-64e9-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 242.407608739,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T19:18:25.043Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-837-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 33.0,
#      'time_since_last_mission': 0,
#      'id': '82abe166-64e9-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '73 Rue de la Fédération, 75015 Paris, France',
#      'distance': 4.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82b586e8-5966-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357476.1497256,
#      'battery': 82.0,
#      'mileage': 1218.0,
#      'location': '48.8520,2.2932',
#      '@timestamp': '2022-01-12T23:41:01.906Z',
#      'end_zipcode': '75015',
#      'week_day': 'Friday',
#      'status': 'FREE',
#      'last_update': '2021-12-10T03:24:59.347Z',
#      '@version': '1',
#      'time_since_last_charge': 3.224170044,
#      'start_charging_date': None,
#      'end_address': '10 Rue George Bernard Shaw, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-10T03:08:59.013Z',
#      'brand': 'Zity',
#      'duration': 16.005515982,
#      'end_location': '48.8520,2.2932',
#      'car_model': 'Spring',
#      'pk_field': '82b586e8-5966-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 244.149725599,
#      'group_id': 'Maintenance',
#      'end__date': '2021-12-10T03:24:59.347Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-034-JY',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 82.0,
#      'time_since_last_mission': 0,
#      'id': '82b586e8-5966-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '10 Rue George Bernard Shaw, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82bb0314-5d04-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5781.828567953,
#      'battery': 74.0,
#      'mileage': 15042.0,
#      'location': '48.8489,2.3026',
#      '@timestamp': '2022-01-12T23:41:02.467Z',
#      'end_zipcode': '75016',
#      'week_day': 'Tuesday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-14T17:57:32.963Z',
#      '@version': '1',
#      'time_since_last_charge': 21.122422675,
#      'start_charging_date': None,
#      'end_address': 'Avenue Georges Lafont, 75016 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-14T17:37:32.720Z',
#      'brand': 'Zity',
#      'duration': 20.003879172,
#      'end_location': '48.8361,2.2558',
#      'car_model': 'Renault ZOE',
#      'pk_field': '82bb0314-5d04-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 354.625756009,
#      'group_id': 'Zity',
#      'end__date': '2021-12-14T17:57:32.963Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-434-JR',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 72.0,
#      'time_since_last_mission': 0,
#      'id': '82bb0314-5d04-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '22 Avenue de Lowendal, 75015 Paris, France',
#      'distance': 5.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82d0263d-684e-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357931.41705944,
#      'battery': 100.0,
#      'mileage': 2545.0,
#      'location': '48.8315,2.2673',
#      '@timestamp': '2022-01-12T23:41:05.678Z',
#      'end_zipcode': '75015',
#      'week_day': 'Wednesday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-29T02:55:02.683Z',
#      '@version': '1',
#      'time_since_last_charge': 4.68039277,
#      'start_charging_date': None,
#      'end_address': 'Rue George Bernard Shaw, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-29T02:25:01.413Z',
#      'brand': 'Zity',
#      'duration': 30.020980047,
#      'end_location': '48.8526,2.2928',
#      'car_model': 'Spring',
#      'pk_field': '82d0263d-684e-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 273.949281659,
#      'group_id': 'Maintenance',
#      'end__date': '2021-12-29T02:55:02.683Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FZ-162-RF',
#      'time_since_last_free': None,
#      'end_battery_level_charge': 0,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 100.0,
#      'time_since_last_mission': 0,
#      'id': '82d0263d-684e-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '9 Rue Camille Desmoulins, 75015 Paris, France',
#      'distance': 3.0,
#      'start_battery_level_charge': 0}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82d8f5dc-5b25-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357529.47834633,
#      'battery': 84.0,
#      'mileage': 11909.0,
#      'location': '48.8414,2.2777',
#      '@timestamp': '2022-01-12T23:41:05.794Z',
#      'end_zipcode': '75015',
#      'week_day': 'Sunday',
#      'status': 'FREE',
#      'last_update': '2021-12-12T23:00:59.527Z',
#      '@version': '1',
#      'time_since_last_charge': 5.678624112,
#      'start_charging_date': None,
#      'end_address': '52 Rue Balard, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-12T08:28:42.047Z',
#      'brand': 'Zity',
#      'duration': 5.998253708,
#      'end_location': '48.8414,2.2777',
#      'car_model': 'Renault ZOE',
#      'pk_field': '82d8f5dc-5b25-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 225.478346334,
#      'group_id': 'Zity',
#      'end__date': '2021-12-12T08:34:41.953Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FA-636-MN',
#      'time_since_last_free': 8403770000,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 84.0,
#      'time_since_last_mission': 0,
#      'id': '82d8f5dc-5b25-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '52 Rue Balard, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '82f17d69-6045-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357686.0071797,
#      'battery': 58.0,
#      'mileage': 1160.0,
#      'location': '48.8380,2.2778',
#      '@timestamp': '2022-01-12T23:41:08.163Z',
#      'end_zipcode': '75015',
#      'week_day': 'Saturday',
#      'status': 'BOOKED_PARKED',
#      'last_update': '2021-12-18T21:10:25.683Z',
#      '@version': '1',
#      'time_since_last_charge': 287.428568591,
#      'start_charging_date': None,
#      'end_address': '176 Rue Saint-Charles, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-18T21:00:25.847Z',
#      'brand': 'Zity',
#      'duration': 9.997086158,
#      'end_location': '48.8408,2.2804',
#      'car_model': 'Spring',
#      'pk_field': '82f17d69-6045-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 382.007179702,
#      'group_id': 'Zity',
#      'end__date': '2021-12-18T21:10:25.683Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-885-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 58.0,
#      'time_since_last_mission': 0,
#      'id': '82f17d69-6045-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '231 Rue St Charles, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '83188a79-5879-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5598.490646763,
#      'battery': 69.0,
#      'mileage': 14898.0,
#      'location': '48.8422,2.3208',
#      '@timestamp': '2022-01-12T23:41:11.298Z',
#      'end_zipcode': '75013',
#      'week_day': 'Wednesday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-08T23:46:31.987Z',
#      '@version': '1',
#      'time_since_last_charge': 73.095605929,
#      'start_charging_date': None,
#      'end_address': '79 Rue du Chevaleret, 75013 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-08T22:52:31.180Z',
#      'brand': 'Zity',
#      'duration': 54.012515288,
#      'end_location': '48.8291,2.3759',
#      'car_model': 'Renault ZOE',
#      'pk_field': '83188a79-5879-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 239.875328152,
#      'group_id': 'Zity',
#      'end__date': '2021-12-08T23:46:31.987Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-476-TV',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 62.0,
#      'time_since_last_mission': 0,
#      'id': '83188a79-5879-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': 'Boulevard de Vaugirard, 75015 Paris, France',
#      'distance': 7.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '832f5f7f-5800-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357433.43836967,
#      'battery': 81.0,
#      'mileage': 959.0,
#      'location': '48.8302,2.2962',
#      '@timestamp': '2022-01-12T23:41:13.080Z',
#      'end_zipcode': '75015',
#      'week_day': 'Wednesday',
#      'status': 'BOOKED_PARKED',
#      'last_update': '2021-12-08T08:30:18.017Z',
#      '@version': '1',
#      'time_since_last_charge': 34.909758556,
#      'start_charging_date': None,
#      'end_address': '14 Rue Jules Dupré, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-08T08:26:18.137Z',
#      'brand': 'Zity',
#      'duration': 3.997933678,
#      'end_location': '48.8302,2.2962',
#      'car_model': 'Spring',
#      'pk_field': '832f5f7f-5800-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 345.438369667,
#      'group_id': 'Zity',
#      'end__date': '2021-12-08T08:30:18.017Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-932-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 81.0,
#      'time_since_last_mission': 0,
#      'id': '832f5f7f-5800-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '14 Rue Jules Dupré, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '833142ca-6410-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357801.85216395,
#      'battery': 42.0,
#      'mileage': 3043.0,
#      'location': '48.8305,2.2960',
#      '@timestamp': '2022-01-12T23:41:13.272Z',
#      'end_zipcode': '75015',
#      'week_day': 'Thursday',
#      'status': 'FREE',
#      'last_update': '2021-12-23T23:03:01.643Z',
#      '@version': '1',
#      'time_since_last_charge': 14.919386171,
#      'start_charging_date': None,
#      'end_address': '57 Rue de Dantzig, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-23T16:51:07.790Z',
#      'brand': 'Zity',
#      'duration': 44.929985645,
#      'end_location': '48.8305,2.2961',
#      'car_model': 'Spring',
#      'pk_field': '833142ca-6410-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 81.222997282,
#      'group_id': 'Zity',
#      'end__date': '2021-12-23T17:36:03.600Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FZ-561-RF',
#      'time_since_last_free': 220876270000,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 42.0,
#      'time_since_last_mission': 0,
#      'id': '833142ca-6410-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '80 Rue de Dantzig, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '8338e257-5a7f-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5663.423477298,
#      'battery': 75.0,
#      'mileage': 12106.0,
#      'location': '48.8518,2.2917',
#      '@timestamp': '2022-01-12T23:41:13.277Z',
#      'end_zipcode': '92100',
#      'week_day': 'Saturday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-11T12:56:26.430Z',
#      '@version': '1',
#      'time_since_last_charge': 40.173443964,
#      'start_charging_date': None,
#      'end_address': '13 Rue Nationale, 92100 Boulogne-Billancourt, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-11T12:40:26.397Z',
#      'brand': 'Zity',
#      'duration': 16.000374647,
#      'end_location': '48.8252,2.2437',
#      'car_model': 'Renault ZOE',
#      'pk_field': '8338e257-5a7f-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 301.67399952,
#      'group_id': 'Zity',
#      'end__date': '2021-12-11T12:56:26.430Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-515-YK',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 73.0,
#      'time_since_last_mission': 0,
#      'id': '8338e257-5a7f-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': 'Rue Desaix, 75015 Paris, France',
#      'distance': 5.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '833b67bb-64e2-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 6000.909659839,
#      'battery': 19.0,
#      'mileage': 15395.0,
#      'location': '48.8281,2.2715',
#      '@timestamp': '2022-01-12T23:41:13.282Z',
#      'end_zipcode': '75015',
#      'week_day': 'Friday',
#      'status': 'FREE',
#      'last_update': '2021-12-24T23:14:20.797Z',
#      '@version': '1',
#      'time_since_last_charge': 112.642441228,
#      'start_charging_date': None,
#      'end_address': '26 Allée des Frères Voisin, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T17:54:23.790Z',
#      'brand': 'Zity',
#      'duration': 26.001180115,
#      'end_location': '48.8281,2.2715',
#      'car_model': 'Renault ZOE',
#      'pk_field': '833b67bb-64e2-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 71.26466345,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T18:20:23.870Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-759-ZW',
#      'time_since_last_free': 52823830000,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 19.0,
#      'time_since_last_mission': 0,
#      'id': '833b67bb-64e2-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '26 Allée des Frères Voisin, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '834fd077-64cf-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357824.63933472,
#      'battery': 32.0,
#      'mileage': 2093.0,
#      'location': '48.8421,2.2864',
#      '@timestamp': '2022-01-12T23:41:14.067Z',
#      'end_zipcode': '75018',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-24T16:40:22.720Z',
#      '@version': '1',
#      'time_since_last_charge': 34.887390278,
#      'start_charging_date': None,
#      'end_address': '9 Rue Paul Albert, 75018 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T15:38:21.610Z',
#      'brand': 'Zity',
#      'duration': 62.018278773,
#      'end_location': '48.8868,2.3450',
#      'car_model': 'Spring',
#      'pk_field': '834fd077-64cf-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 263.992668056,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T16:40:22.720Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-868-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 25.0,
#      'time_since_last_mission': 0,
#      'id': '834fd077-64cf-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '3 Rue Sarasate, 75015 Paris, France',
#      'distance': 10.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '77003b4b-5f28-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357651.99890254,
#      'battery': 81.0,
#      'mileage': 2803.0,
#      'location': '48.8470,2.3067',
#      '@timestamp': '2022-01-12T23:37:37.102Z',
#      'end_zipcode': '75015',
#      'week_day': 'Friday',
#      'status': 'FREE',
#      'last_update': '2021-12-18T12:59:18.787Z',
#      '@version': '1',
#      'time_since_last_charge': 89.265848372,
#      'start_charging_date': None,
#      'end_address': '32B Rue Pérignon, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-17T10:59:56.053Z',
#      'brand': 'Zity',
#      'duration': 1559.378750658,
#      'end_location': '48.8469,2.3066',
#      'car_model': 'Spring',
#      'pk_field': '77003b4b-5f28-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 443.998902539,
#      'group_id': 'Zity',
#      'end__date': '2021-12-18T12:59:18.787Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FZ-123-RF',
#      'time_since_last_free': 39825600000,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 80.0,
#      'time_since_last_mission': 0,
#      'id': '77003b4b-5f28-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '32 Rue Pérignon, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '770915ad-56dc-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5549.943445582,
#      'battery': 82.0,
#      'mileage': 12063.0,
#      'location': '48.8529,2.2859',
#      '@timestamp': '2022-01-12T23:37:37.692Z',
#      'end_zipcode': '75015',
#      'week_day': 'Monday',
#      'status': 'FREE',
#      'last_update': '2021-12-07T19:06:05.407Z',
#      '@version': '1',
#      'time_since_last_charge': 8.039838082,
#      'start_charging_date': None,
#      'end_address': '28 Quai de Grenelle, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-06T21:35:44.417Z',
#      'brand': 'Zity',
#      'duration': 1290.349726268,
#      'end_location': '48.8528,2.2859',
#      'car_model': 'Renault ZOE',
#      'pk_field': '770915ad-56dc-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 152.405671416,
#      'group_id': 'Zity',
#      'end__date': '2021-12-07T19:06:05.407Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-802-ZW',
#      'time_since_last_free': 12033400000,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 80.0,
#      'time_since_last_mission': 0,
#      'id': '770915ad-56dc-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '6 Port de Grenelle, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '770915b2-56dc-11ec-8b8f-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357398.59573946,
#      'battery': 18.0,
#      'mileage': 1959.0,
#      'location': '48.8536,2.2893',
#      '@timestamp': '2022-01-12T23:37:37.692Z',
#      'end_zipcode': '75015',
#      'week_day': 'Monday',
#      'status': 'BOOKED_PARKED',
#      'last_update': '2021-12-06T21:59:44.820Z',
#      '@version': '1',
#      'time_since_last_charge': 67.187683905,
#      'start_charging_date': None,
#      'end_address': '8 Boulevard de Grenelle, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-06T21:35:44.663Z',
#      'brand': 'Zity',
#      'duration': 24.002562125,
#      'end_location': '48.8536,2.2893',
#      'car_model': 'Spring',
#      'pk_field': '770915b2-56dc-11ec-8b8f-000d3a89d198',
#      'time_since_last_cleaning': 2357398.59573946,
#      'group_id': 'Zity',
#      'end__date': '2021-12-06T21:59:44.820Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FZ-724-RF',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 18.0,
#      'time_since_last_mission': 0,
#      'id': '770915b2-56dc-11ec-8b8f-000d3a89d198',
#      'car_id': None,
#      'address': '8 Boulevard de Grenelle, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '771675d2-6f0e-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 0,
#      'battery': 59.0,
#      'mileage': 2163.0,
#      'location': '48.843560000,2.282860000',
#      '@timestamp': '2022-01-12T23:37:39.495Z',
#      'end_zipcode': '75015',
#      'week_day': 'Thursday',
#      'status': 'BOOKED_PARKED',
#      'last_update': '2022-01-06T17:47:49.320Z',
#      '@version': '1',
#      'time_since_last_charge': 0,
#      'start_charging_date': None,
#      'end_address': '50 Avenue Félix Faure, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2022-01-06T15:27:09.153Z',
#      'brand': 'Zity',
#      'duration': 140.669394277,
#      'end_location': '48.840840000,2.287110000',
#      'car_model': 'Spring',
#      'pk_field': '771675d2-6f0e-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 2358126.56860635,
#      'group_id': 'Client',
#      'end__date': '2022-01-06T16:37:13.950Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-082-JY',
#      'time_since_last_free': None,
#      'end_battery_level_charge': 0,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 44.0,
#      'time_since_last_mission': 0,
#      'id': '771675d2-6f0e-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '137 Rue Saint-Charles, 75015 Paris, France',
#      'distance': 15.0,
#      'start_battery_level_charge': 0}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '7722cfbd-60df-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5852.256369213,
#      'battery': 14.0,
#      'mileage': 15199.0,
#      'location': '48.8281,2.2716',
#      '@timestamp': '2022-01-12T23:37:46.774Z',
#      'end_zipcode': '75015',
#      'week_day': 'Sunday',
#      'status': 'FREE',
#      'last_update': '2021-12-19T17:05:33.343Z',
#      '@version': '1',
#      'time_since_last_charge': 0.041631158,
#      'start_charging_date': None,
#      'end_address': '26 Allée des Frères Voisin, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-19T15:22:31.873Z',
#      'brand': 'Zity',
#      'duration': 103.024147327,
#      'end_location': '48.8281,2.2716',
#      'car_model': 'Renault ZOE',
#      'pk_field': '7722cfbd-60df-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 472.375520046,
#      'group_id': 'Maintenance',
#      'end__date': '2021-12-19T17:05:33.343Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-062-TV',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 91.0,
#      'time_since_last_mission': 0,
#      'id': '7722cfbd-60df-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '26 Allée des Frères Voisin, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '7722cfd6-60df-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5853.723653126,
#      'battery': 88.0,
#      'mileage': 12508.0,
#      'location': '48.8396,2.2852',
#      '@timestamp': '2022-01-12T23:37:46.774Z',
#      'end_zipcode': '75015',
#      'week_day': 'Sunday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-19T15:38:32.173Z',
#      '@version': '1',
#      'time_since_last_charge': 30.933438404,
#      'start_charging_date': None,
#      'end_address': 'Place Jacques et Thérèse Trefouël, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-19T15:22:32.377Z',
#      'brand': 'Zity',
#      'duration': 15.995964027,
#      'end_location': '48.8422,2.3132',
#      'car_model': 'Renault ZOE',
#      'pk_field': '7722cfd6-60df-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 496.375660626,
#      'group_id': 'Zity',
#      'end__date': '2021-12-19T15:38:32.173Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FB-542-TV',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 87.0,
#      'time_since_last_mission': 0,
#      'id': '7722cfd6-60df-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '3 Rue Jean Maridor, 75015 Paris, France',
#      'distance': 3.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '77267c84-64c4-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357823.32222008,
#      'battery': 92.0,
#      'mileage': 15176.0,
#      'location': '48.8422,2.2875',
#      '@timestamp': '2022-01-12T23:37:47.195Z',
#      'end_zipcode': '75015',
#      'week_day': 'Friday',
#      'status': 'FREE',
#      'last_update': '2021-12-24T23:14:33.143Z',
#      '@version': '1',
#      'time_since_last_charge': 3.629164522,
#      'start_charging_date': None,
#      'end_address': '14 Rue Oscar Roty, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T14:19:19.993Z',
#      'brand': 'Zity',
#      'duration': 26.00674018,
#      'end_location': '48.8422,2.2875',
#      'car_model': 'Renault ZOE',
#      'pk_field': '77267c84-64c4-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 332.880275633,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T14:45:20.417Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FA-238-MP',
#      'time_since_last_free': 12018960000,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 92.0,
#      'time_since_last_mission': 0,
#      'id': '77267c84-64c4-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '14 Rue Oscar Roty, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '772ec596-6027-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357682.42283974,
#      'battery': 92.0,
#      'mileage': 15221.0,
#      'location': '48.8525,2.2928',
#      '@timestamp': '2022-01-12T23:37:50.993Z',
#      'end_zipcode': '75015',
#      'week_day': 'Saturday',
#      'status': 'BOOKED_PARKED',
#      'last_update': '2021-12-18T17:49:22.567Z',
#      '@version': '1',
#      'time_since_last_charge': 290.443395291,
#      'start_charging_date': None,
#      'end_address': 'Rue George Bernard Shaw, 75015 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-18T17:25:22.223Z',
#      'brand': 'Zity',
#      'duration': 24.0054103,
#      'end_location': '48.8525,2.2928',
#      'car_model': 'Renault ZOE',
#      'pk_field': '772ec596-6027-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 474.422839735,
#      'group_id': 'Zity',
#      'end__date': '2021-12-18T17:49:22.567Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'FA-866-MN',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 92.0,
#      'time_since_last_mission': 0,
#      'id': '772ec596-6027-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': 'Rue George Bernard Shaw, 75015 Paris, France',
#      'distance': 0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '77314e6e-64fe-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 2357830.24081542,
#      'battery': 84.0,
#      'mileage': 1746.0,
#      'location': '48.8330,2.2923',
#      '@timestamp': '2022-01-12T23:37:51.368Z',
#      'end_zipcode': '75005',
#      'week_day': 'Friday',
#      'status': 'BOOKED',
#      'last_update': '2021-12-24T22:08:27.493Z',
#      '@version': '1',
#      'time_since_last_charge': 41.209426529,
#      'start_charging_date': None,
#      'end_address': '26 Rue Censier, 75005 Paris, France',
#      'table_name': 'carshare_car_history',
#      'city': 'Paris',
#      'start_date': '2021-12-24T21:14:26.937Z',
#      'brand': 'Zity',
#      'duration': 54.009067995,
#      'end_location': '48.8404,2.3522',
#      'car_model': 'Spring',
#      'pk_field': '77314e6e-64fe-11ec-8b90-000d3a89d198',
#      'time_since_last_cleaning': 252.652759863,
#      'group_id': 'Zity',
#      'end__date': '2021-12-24T22:08:27.493Z',
#      'previous_booking_id': None,
#      'car_plate_number': 'GB-938-JX',
#      'time_since_last_free': None,
#      'end_battery_level_charge': None,
#      'driver': None,
#      'zipcode': '75015',
#      'end_battery': 67.0,
#      'time_since_last_mission': 0,
#      'id': '77314e6e-64fe-11ec-8b90-000d3a89d198',
#      'car_id': None,
#      'address': '42 Rue Vaugelas, 75015 Paris, France',
#      'distance': 18.0,
#      'start_battery_level_charge': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '7736d87b-60c5-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'time_since_last_movement': 5850.284067367,
#      'battery': 82.0,
#      'mileage': 13140.0,
#      'location': '48.8365,2.3021',
#      '@timestamp': '2022-01-12T23:37:53.677Z',
#      'end_zipcode': '75015',
#      'week_day': 'Sunday',
#      'status': 'FREE',
#      'last_update': '2021-12-19T23:00:45.963Z',
#      '@version': '1',
# ...
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FZ-411-RF',
#      'end_zipcode': '75015',
#      'car_model': 'Spring',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Wednesday',
#      'dd': None,
#      'end_time': None,
#      'address': '34 Allée des Frères Voisin, 75015 Paris, France',
#      'location': '48.8290,2.2717',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-25T20:09:47.573Z',
#      '@timestamp': '2021-09-15T22:01:26.664Z',
#      'time_since_last_cleaning': 2354926.16321521,
#      'table_name': 'carshare_car_history',
#      'distance': 1.0,
#      'mileage': 610.0,
#      'end_address': 'Allée des Frères Voisin, 75015 Paris, France',
#      'status': 'FREE',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-25T20:10:47.587Z',
#      'time_since_last_movement': 2354926.16321521,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': 100819160000,
#      'id': '60ea682d-05e0-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-25T22:03:33.443Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '60f8cb58-ff58-11eb-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 30.0,
#      'time_since_last_charge': 2354726.68635368,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8406,2.3547',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 15.0,
#      'duration': 47.008745923,
#      'pk_field': '60f8cb58-ff58-11eb-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FZ-561-RF',
#      'end_zipcode': '75005',
#      'car_model': 'Spring',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Tuesday',
#      'dd': None,
#      'end_time': None,
#      'address': "17 Rue de l'Arrivée, 75015 Paris, France",
#      'location': '48.8429,2.3220',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-17T12:41:10.873Z',
#      '@timestamp': '2021-09-15T22:01:26.669Z',
#      'time_since_last_cleaning': 2354726.68635368,
#      'table_name': 'carshare_car_history',
#      'distance': 4.0,
#      'mileage': 637.0,
#      'end_address': '15 Rue Censier, 75005 Paris, France',
#      'status': 'BOOKED',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-17T13:28:11.403Z',
#      'time_since_last_movement': 2354726.68635368,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': None,
#      'id': '60f8cb58-ff58-11eb-8b8b-000d3a89d198',
#      'last_update': '2021-08-17T13:28:11.403Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '6102ee4b-0833-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 78.0,
#      'time_since_last_charge': 18.232712535,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8388,2.2866',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 78.0,
#      'duration': 9.99729108,
#      'pk_field': '6102ee4b-0833-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FB-403-JS',
#      'end_zipcode': '75015',
#      'car_model': 'Renault ZOE',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Saturday',
#      'dd': None,
#      'end_time': None,
#      'address': '21 Rue Jean Maridor, 75015 Paris, France',
#      'location': '48.8389,2.2866',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-28T19:08:59.767Z',
#      '@timestamp': '2021-09-15T22:01:26.684Z',
#      'time_since_last_cleaning': 201.837712535,
#      'table_name': 'carshare_car_history',
#      'distance': 0,
#      'mileage': 11571.0,
#      'end_address': '21 Rue Jean Maridor, 75015 Paris, France',
#      'status': 'BOOKED_PARKED',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-28T19:18:59.613Z',
#      'time_since_last_movement': 3150.68063948,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': None,
#      'id': '6102ee4b-0833-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-28T19:18:59.613Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '6104c005-0586-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 6.0,
#      'time_since_last_charge': 0.145659553,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8299,2.2915',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 6.0,
#      'duration': 0.998567652,
#      'pk_field': '6104c005-0586-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FA-309-MP',
#      'end_zipcode': '75015',
#      'car_model': 'Renault ZOE',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Wednesday',
#      'dd': None,
#      'end_time': None,
#      'address': 'Rue de la Recherche, 75015 Paris, France',
#      'location': '48.8299,2.2915',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-25T09:25:34.373Z',
#      '@timestamp': '2021-09-15T22:01:26.684Z',
#      'time_since_last_cleaning': 336.566770664,
#      'table_name': 'carshare_car_history',
#      'distance': 0,
#      'mileage': 12219.0,
#      'end_address': 'Rue de la Recherche, 75015 Paris, France',
#      'status': 'FREE',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-25T09:26:34.330Z',
#      'time_since_last_movement': 2354915.42621511,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': 374464060000,
#      'id': '6104c005-0586-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-25T22:06:25.133Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '6104c006-0586-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 35.0,
#      'time_since_last_charge': 350.986519276,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8318,2.2954',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 35.0,
#      'duration': 2.000636253,
#      'pk_field': '6104c006-0586-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FB-774-JS',
#      'end_zipcode': '75015',
#      'car_model': 'Renault ZOE',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Wednesday',
#      'dd': None,
#      'end_time': None,
#      'address': '76 Rue de Dantzig, 75015 Paris, France',
#      'location': '48.8308,2.2962',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-25T09:25:34.470Z',
#      '@timestamp': '2021-09-15T22:01:26.684Z',
#      'time_since_last_cleaning': 286.335130387,
#      'table_name': 'carshare_car_history',
#      'distance': -1.0,
#      'mileage': 13245.0,
#      'end_address': '22 Rue de la Saïda, 75015 Paris, France',
#      'status': 'FREE',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-25T09:27:34.510Z',
#      'time_since_last_movement': 3068.590379553,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': 1898570000,
#      'id': '6104c006-0586-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-25T22:04:14.963Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '610cfa7a-0125-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 30.0,
#      'time_since_last_charge': 0.358510453,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8517,2.2936',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 32.0,
#      'duration': 33.003282907,
#      'pk_field': '610cfa7a-0125-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FB-172-TV',
#      'end_zipcode': '75015',
#      'car_model': 'Renault ZOE',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Thursday',
#      'dd': None,
#      'end_time': None,
#      'address': '21 Rue George Bernard Shaw, 75015 Paris, France',
#      'location': '48.8517,2.2936',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-19T19:41:05.637Z',
#      '@timestamp': '2021-09-15T22:01:26.774Z',
#      'time_since_last_cleaning': 56.614343786,
#      'table_name': 'carshare_car_history',
#      'distance': 0,
#      'mileage': 11342.0,
#      'end_address': '21 Rue George Bernard Shaw, 75015 Paris, France',
#      'status': 'BOOKED_PARKED',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-19T20:14:05.890Z',
#      'time_since_last_movement': 2932.783437397,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': None,
#      'id': '610cfa7a-0125-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-19T20:14:05.890Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '6117d598-08dd-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 27.0,
#      'time_since_last_charge': 93.192290284,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8459,2.2882',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 27.0,
#      'duration': 3.000722375,
#      'pk_field': '6117d598-08dd-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FB-530-TV',
#      'end_zipcode': '75015',
#      'car_model': 'Renault ZOE',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Sunday',
#      'dd': None,
#      'end_time': None,
#      'address': '31 Rue Émeriau, 75015 Paris, France',
#      'location': '48.8498,2.2867',
#      'group_id': 'Maintenance',
#      'city': 'Paris',
#      'start_date': '2021-08-29T15:25:46.247Z',
#      '@timestamp': '2021-09-15T22:01:26.774Z',
#      'time_since_last_cleaning': 102.149234728,
#      'table_name': 'carshare_car_history',
#      'distance': 2.0,
#      'mileage': 12607.0,
#      'end_address': '72B Rue de Lourmel, 75015 Paris, France',
#      'status': 'BOOKED',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-29T15:28:46.293Z',
#      'time_since_last_movement': 3158.859974451,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': None,
#      'id': '6117d598-08dd-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-29T15:28:46.293Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '613e0741-033c-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 15.0,
#      'time_since_last_charge': 247.109921359,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8358,2.2816',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 15.0,
#      'duration': 1.000473535,
#      'pk_field': '613e0741-033c-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FZ-462-RF',
#      'end_zipcode': '75015',
#      'car_model': 'Spring',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Sunday',
#      'dd': None,
#      'end_time': None,
#      'address': '365 Rue Lecourbe, 75015 Paris, France',
#      'location': '48.8358,2.2816',
#      'group_id': 'Maintenance',
#      'city': 'Paris',
#      'start_date': '2021-08-22T11:30:41.717Z',
#      '@timestamp': '2021-09-15T22:01:26.888Z',
#      'time_since_last_cleaning': 2354845.51158803,
#      'table_name': 'carshare_car_history',
#      'distance': 0,
#      'mileage': 466.0,
#      'end_address': '365 Rue Lecourbe, 75015 Paris, France',
#      'status': 'BOOKED',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-22T11:31:41.750Z',
#      'time_since_last_movement': 2354845.51158803,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': None,
#      'id': '613e0741-033c-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-22T11:31:41.750Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '61468a3b-0025-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 20.0,
#      'time_since_last_charge': 506.641625581,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8504,2.2990',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 20.0,
#      'duration': 55.022903243,
#      'pk_field': '61468a3b-0025-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FB-370-TV',
#      'end_zipcode': '75015',
#      'car_model': 'Renault ZOE',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Wednesday',
#      'dd': None,
#      'end_time': None,
#      'address': '1 Avenue Paul Déroulède, 75015 Paris, France',
#      'location': '48.8504,2.2990',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-18T13:08:34.853Z',
#      '@timestamp': '2021-09-15T22:01:26.888Z',
#      'time_since_last_cleaning': 167.736070025,
#      'table_name': 'carshare_car_history',
#      'distance': 0,
#      'mileage': 12634.0,
#      'end_address': '1 Avenue Paul Déroulède, 75015 Paris, France',
#      'status': 'FREE',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-18T14:03:36.237Z',
#      'time_since_last_movement': 2902.190330303,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': 11699260000,
#      'id': '61468a3b-0025-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-18T22:01:06.613Z',
#      'list_of_zone': None}},
#    {'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '61468a3c-0025-11ec-8b8b-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'driver': None,
#      'car_id': None,
#      'end_battery': 19.0,
#      'time_since_last_charge': 0.409697803,
#      'brand': 'Zity',
#      'weather': None,
#      'end_location': '48.8280,2.2916',
#      'previous_booking_id': None,
#      'is_charging__analysis': None,
#      'battery': 19.0,
#      'duration': 0.995561225,
#      'pk_field': '61468a3c-0025-11ec-8b8b-000d3a89d198',
#      '@version': '1',
#      'time_since_last_mission': 0,
#      'car_plate_number': 'FB-386-YK',
#      'end_zipcode': '75015',
#      'car_model': 'Renault ZOE',
#      'zipcode': '75015',
#      'end_zone': None,
#      'week_day': 'Wednesday',
#      'dd': None,
#      'end_time': None,
#      'address': 'Rue de la Recherche, 75015 Paris, France',
#      'location': '48.8280,2.2916',
#      'group_id': 'Zity',
#      'city': 'Paris',
#      'start_date': '2021-08-18T13:08:34.913Z',
#      '@timestamp': '2021-09-15T22:01:26.888Z',
#      'time_since_last_cleaning': 120.670531136,
#      'table_name': 'carshare_car_history',
#      'distance': 0,
#      'mileage': 11242.0,
#      'end_address': 'Rue de la Recherche, 75015 Paris, France',
#      'status': 'FREE',
#      'is_start_of_customer_booking': None,
#      'start_hour': '1752-12-31T23:50:39.000Z',
#      'end__date': '2021-08-18T13:09:34.650Z',
#      'time_since_last_movement': 2903.209474747,
#      'end__hour': '1752-12-31T23:50:39.000Z',
#      'time_since_last_free': 22229960000,
#      'id': '61468a3c-0025-11ec-8b8b-000d3a89d198',
#      'last_update': '2021-08-18T22:03:38.127Z',
#      'list_of_zone': None}},
#    ...]}}

# %%
print(len(result['hits']['hits']))
# Out:
# 116730

# %% [markdown]
# ## Convert data to dataframe

# %%
df = pd.json_normalize(result['hits']['hits'])
df = df[['_source.end__date', '_source.car_plate_number', '_source.status', '_source.group_id', '_source.duration', '_source.distance', '_source.location', '_source.zipcode', '_source.battery', '_source.end_battery']]
df
# Out:
#                         _source.end__date _source.car_plate_number  \
# 0                2021-12-10T20:51:13.600Z                FZ-162-RF
# 1                2021-12-26T14:39:03.447Z                GB-996-JX
# 2                2021-12-15T18:51:54.027Z                FB-627-JR
# 3                2021-12-26T17:25:06.463Z                GB-972-JX
# 4                2021-12-14T14:41:30.530Z                FB-726-JR
# ...                                   ...                      ...
# 116725  2022-05-08T21:21:43.7907247+02:00                FZ-989-RF
# 116726  2022-05-08T21:21:46.3787991+02:00                GB-033-JY
# 116727  2022-05-08T21:22:05.2249618+02:00                FZ-910-RF
# 116728  2022-05-08T21:22:26.8359542+02:00                GB-067-JY
# 116729  2022-05-08T21:22:33.7769983+02:00                FZ-275-RF
#
#        _source.status _source.group_id  _source.duration  _source.distance  \
# 0              BOOKED             Zity          9.999589               2.0
# 1                FREE             Zity       1124.272803               0.0
# 2       BOOKED_PARKED             Zity          3.994547               0.0
# 3              BOOKED             Zity         16.015235               3.0
# 4                FREE      Maintenance         10.002449               0.0
# ...               ...              ...               ...               ...
# 116725           FREE           Client        125.000000               1.0
# 116726  BOOKED_PARKED           Client         39.000000               0.0
# 116727           FREE           Client         39.000000               2.0
# 116728         BOOKED           Client         39.000000              10.0
# 116729           FREE           Client        125.000000               0.0
#
#               _source.location _source.zipcode  _source.battery  \
# 0               48.8342,2.3084           75015             20.0
# 1               48.8510,2.2844           75015             33.0
# 2               48.8299,2.2682           75015             86.0
# 3               48.8471,2.2851           75015             22.0
# 4               48.8386,2.2721           75015             96.0
# ...                        ...             ...              ...
# 116725    48.8390274,2.2878294           75015            100.0
# 116726  48.84534454,2.29740763           75015             73.0
# 116727   48.8347168,2.28977203           75015             78.0
# 116728  48.83942795,2.30699611           75015             24.0
# 116729  48.83959198,2.30971146           75015             29.0
#
#         _source.end_battery
# 0                      19.0
# 1                      33.0
# 2                      86.0
# 3                      20.0
# 4                      96.0
# ...                     ...
# 116725                 99.0
# 116726                 73.0
# 116727                 77.0
# 116728                 17.0
# 116729                 29.0
#
# [116730 rows x 10 columns]

# %%
print(df['_source.group_id'].value_counts())
print(df['_source.status'].unique())
print((df['_source.end__date'].str[:7].value_counts()))
print(len(df['_source.car_plate_number'].unique()))
# Out:
# Zity              85100
# Maintenance       16241
# Client             7498
# Battery            4132
# Workshop           3622
# Zity Corporate       81
# Airport              42
# 14                    9
# MAINTENANCE           5
# Name: _source.group_id, dtype: int64
# ['BOOKED' 'FREE' 'BOOKED_PARKED' 'RESERVED' 'UNRESPONSIVE']
# 2021-12    10267
# 2021-07    10204
# 2021-05     9800
# 2021-08     9768
# 2021-10     9546
# 2021-09     9472
# 2021-04     9254
# 2021-06     9180
# 2021-11     8908
# 2021-03     6474
# 2021-02     6244
# 2020-12     4660
# 2021-01     3284
# 2022-01     3144
# 2022-02     3065
# 2022-03     1175
# 2022-05      779
# 2020-11      735
# 1752-12      733
# 2022-04       18
# 1753-01       16
# 0001-01        4
# Name: _source.end__date, dtype: int64
# 790

# %% [markdown]
# ### Utils

# %%
month_duration_dict = {"Jan": 31, "Feb": 28, "Mar": 31, "Apr": 30, "May": 31, "Jun": 30, "Jul": 31, "Aug": 31, "Sep": 30, "Oct": 31, "Nov": 30, "Dec": 31}

durations = np.array(list(month_duration_dict.values()))
cum_durations = np.cumsum(durations)
cum_dict = {i+1: cum_durations[i] for i in range(len(cum_durations))}
cum_dict[0]=0

week_dict = {"Monday": 0, "Tuesday": 1, "Wednesday": 2, "Thursday": 3, "Friday": 4, "Saturday": 5, "Sunday": 6}

monthdict = {"Jan": 0, "Feb": 1, "Mar": 2,
        "Apr": 3,
        "May": 4,
        "Jun": 5,
        "Jul": 6,
        "Aug": 7,
        "Sep": 8,
        "Oct": 9,
        "Nov": 10, 
        "Dec": 11
    }

inv_month = {v: k for k, v in monthdict.items()}

# %% [markdown]
# ### Map values

# %%
df['_source.group_id'].replace("Zity", "Client", inplace=True) # Map Zity to Client
df['_source.group_id'].replace("Zity Corporate", "Defleeted", inplace=True) # Map Zity Corporate to Defleeted
df.rename(columns = {'_source.end__date':'end_date', '_source.car_plate_number':'car_plate_number', '_source.status':'status', '_source.group_id':'group_id', '_source.duration':'kibana_duration', '_source.distance':'distance', '_source.location':'location', '_source.zipcode':'zipcode'}, inplace = True)

# %% [markdown]
# ### Splitting and creating columns

# %%
df['delta_battery']=df['_source.end_battery']-df['_source.battery']
df.drop('_source.end_battery', axis=1, inplace=True)
df.drop('_source.battery', axis=1, inplace=True)
df[['latitude', 'longitude']] = df['location'].str.split(',', expand=True)
df.drop('location', axis=1, inplace=True)
df['kibana_duration'] = df['kibana_duration'].astype(str)
df[['kibana_duration', 'trash']] = df['kibana_duration'].str.split('.', expand=True)
df.drop('trash', axis=1, inplace=True)
df[['end_date', 'end_time']] = df['end_date'].str.split('T', expand=True)
df[['end_time', 'trash']] = df['end_time'].str.split('.', expand=True)
df.drop('trash', axis=1, inplace=True)
df[['end_year', 'end_month', "end_day_number"]] = df['end_date'].str.split('-', expand=True)
df.drop('end_date', axis=1, inplace=True)
df[['end_hour', 'end_minutes', "end_seconds"]] = df['end_time'].str.split(':', expand=True)
df.drop('end_time', axis=1, inplace=True)
df.drop('end_seconds', axis=1, inplace=True)
df
# Out:
#        car_plate_number         status     group_id kibana_duration  distance  \
# 0             FZ-162-RF         BOOKED       Client               9       2.0
# 1             GB-996-JX           FREE       Client            1124       0.0
# 2             FB-627-JR  BOOKED_PARKED       Client               3       0.0
# 3             GB-972-JX         BOOKED       Client              16       3.0
# 4             FB-726-JR           FREE  Maintenance              10       0.0
# ...                 ...            ...          ...             ...       ...
# 116725        FZ-989-RF           FREE       Client             125       1.0
# 116726        GB-033-JY  BOOKED_PARKED       Client              39       0.0
# 116727        FZ-910-RF           FREE       Client              39       2.0
# 116728        GB-067-JY         BOOKED       Client              39      10.0
# 116729        FZ-275-RF           FREE       Client             125       0.0
#
#        zipcode  delta_battery     latitude   longitude end_year end_month  \
# 0        75015           -1.0      48.8342      2.3084     2021        12
# 1        75015            0.0      48.8510      2.2844     2021        12
# 2        75015            0.0      48.8299      2.2682     2021        12
# 3        75015           -2.0      48.8471      2.2851     2021        12
# 4        75015            0.0      48.8386      2.2721     2021        12
# ...        ...            ...          ...         ...      ...       ...
# 116725   75015           -1.0   48.8390274   2.2878294     2022        05
# 116726   75015            0.0  48.84534454  2.29740763     2022        05
# 116727   75015           -1.0   48.8347168  2.28977203     2022        05
# 116728   75015           -7.0  48.83942795  2.30699611     2022        05
# 116729   75015            0.0  48.83959198  2.30971146     2022        05
#
#        end_day_number end_hour end_minutes
# 0                  10       20          51
# 1                  26       14          39
# 2                  15       18          51
# 3                  26       17          25
# 4                  14       14          41
# ...               ...      ...         ...
# 116725             08       21          21
# 116726             08       21          21
# 116727             08       21          22
# 116728             08       21          22
# 116729             08       21          22
#
# [116730 rows x 14 columns]

# %% [markdown]
# ### Change types

# %%
df['distance']= pd.to_numeric(df['distance'], errors='coerce')
df['distance'] = df['distance'].fillna(0)
df['latitude'] = pd.to_numeric(df['latitude'], errors='coerce')
df['longitude'] = pd.to_numeric(df['longitude'], errors='coerce')
df['zipcode'] = pd.to_numeric(df['zipcode'], errors='coerce')
df['kibana_duration'] = pd.to_numeric(df['kibana_duration'], errors='coerce')
df['end_year'] = pd.to_numeric(df['end_year'], errors='coerce')
df['end_month'] = pd.to_numeric(df['end_month'], errors='coerce')
df['end_day_number'] = pd.to_numeric(df['end_day_number'], errors='coerce')
df['end_hour'] = pd.to_numeric(df['end_hour'], errors='coerce')
df['end_minutes'] = pd.to_numeric(df['end_minutes'], errors='coerce')

# %% [markdown]
# ### Calculate end time since 2020

# %%
df['time_since_2020'] = (df['end_year']-2020)*365*24*60 + ((df['end_month']-1).map(cum_dict)+df['end_day_number'])*24*60 + df['end_hour']*60 + df['end_minutes']

# %% [markdown]
# ### Sort by end date

# %%
df = df.sort_values(by='time_since_2020', ascending = False)
df.reset_index(drop=True, inplace = True)

# %% [markdown]
# ## Calculation of the durations
#
# Only the end dates are reliable. The start date for a given segment corresponds to the last end date for the same plate.

# %%
def latest_segment(index):
    # returns index of the latest segment for the same plate
    
    plate_segments = list(df.loc[df['car_plate_number']==df.loc[index, 'car_plate_number']].index)
    previous_segments = plate_segments[plate_segments.index(index)+1:]
    if not len(previous_segments):
        return -1
    return previous_segments[0]

# %%
def next_segment(index):
    plate_segments = list(df.loc[df['car_plate_number']==df.loc[index, 'car_plate_number']].index)
    if plate_segments.index(index)==0:
        return -1
    return plate_segments[plate_segments.index(index)-1]

# %%
def duration(index):
    # returns the duration for a given index, only takes into account days and time
    
    previous_index = latest_segment(index)
    if previous_index==-1:
        return 0
    return df.loc[index, 'time_since_2020'] - df.loc[previous_index, 'time_since_2020']

# %% [markdown]
# Durations should be calculated on data not restricted to a specific district otherwise it makes no sense to look for the last occurence of the same plate as the car have travelled tto another district !

# %%
#df['duration']=df.index.map(duration)
df['duration']=df['kibana_duration'] 
df
# Out:
#        car_plate_number  status     group_id  kibana_duration  distance  \
# 0             FZ-431-RF    FREE       Client              142       0.0
# 1             GB-797-JX    FREE       Client              162       0.0
# 2             FZ-797-RF    FREE       Client              118       4.0
# 3             GD-930-TQ    FREE      Battery              594       4.0
# 4             GB-952-JX  BOOKED       Client               37       5.0
# ...                 ...     ...          ...              ...       ...
# 116725        GB-829-JX  BOOKED       Client                0       0.0
# 116726        GB-045-JY    FREE  Maintenance                0       0.0
# 116727        GB-805-JX  BOOKED       Client                0       0.0
# 116728        FZ-675-RF  BOOKED       Client                0       0.0
# 116729        FZ-975-RF  BOOKED  Maintenance                0       0.0
#
#         zipcode  delta_battery   latitude  longitude  end_year  end_month  \
# 0         75015            0.0  48.841396   2.302687      2022          5
# 1         75015           54.0  48.828094   2.271857      2022          5
# 2         75015           -2.0  48.840595   2.288074      2022          5
# 3         75015           69.0  48.828358   2.271328      2022          5
# 4         75015           -2.0  48.850243   2.348434      2022          5
# ...         ...            ...        ...        ...       ...        ...
# 116725    75015          -95.0  48.843810   2.315260      1752         12
# 116726    75015            0.0  48.842910   2.321860         1          1
# 116727    75015          -24.0  48.846610   2.286550         1          1
# 116728    75015          -58.0  48.840690   2.290980         1          1
# 116729    75015           -5.0  48.835370   2.268180         1          1
#
#         end_day_number  end_hour  end_minutes  time_since_2020  duration
# 0                    9         1           46          1237066       142
# 1                    9         1           23          1237043       162
# 2                    9         1           21          1237041       118
# 3                    9         1           21          1237041       594
# 4                    9         1           21          1237041        37
# ...                ...       ...          ...              ...       ...
# 116725              31        23           50       -140333770         0
# 116726               1         0            0      -1061184960         0
# 116727               1         0            0      -1061184960         0
# 116728               1         0            0      -1061184960         0
# 116729               1         0            0      -1061184960         0
#
# [116730 rows x 16 columns]

# %% [markdown]
# ## Keep only "CLIENT" Group-ids

# %%
df = df[df['group_id']=="Client"]

# %% [markdown]
# ## Corrrect bugs

# %% [markdown]
# ### Fake booking BUG
#
# Some segments have a "Booked" status but no distance is covered. The status of these fake entries is changed to "FREE"
#
# Unit test : index #255 & #256 (GB-102-JY)

# %%
def new_status(index):
    status = df.loc[index, 'status']
    distance = df.loc[index, 'distance']
    if (status=="BOOKED" or status=="BOOKED_PARK") and distance==0:
        return "FREE"
    return status

df['status']=df.index.map(new_status)
# Out:
# <ipython-input-20-7dd7bf9ab8d1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['status']=df.index.map(new_status)

# %% [markdown]
# ### Missing locations BUG
#
# In April, 2022, the locations are missins. The corresponding rows should be deleted

# %%
df = df[df['latitude'].notna()]
df = df[df['longitude'].notna()]

# %% [markdown]
# ### Fake year BUG
# Some data are from 1753

# %%
df = df[df['end_year']>2000]

# %% [markdown]
# ## Interpolation of useless segments
#
# For a given plate, a FREE segment should be followed in time by a BOOKED or BOOKED_PARK segment and vice-versa. To do before the calculation of the durations.
#
# Unit test : index #253 -> #283 (GB-102-JY) #628 (GB-029-JY)

# %%
def has_changed_status(index):
    last_index = latest_segment(index)
    if last_index==-1:
        return True
    return df.loc[index, 'status']!=df.loc[last_index, 'status']

# %%
df['Status_has_changed']=df.index.map(has_changed_status)

# %%
def new_feature(index, feature_name):
    # returns the feature value for the last segment which status didn't change
    
    if df.loc[index, 'Status_has_changed']:
        return df.loc[index, feature_name]
    else :
        index_list = list(df.loc[df['car_plate_number']==df.loc[index, 'car_plate_number']].index)
        bool_list = list(df.loc[df['car_plate_number']==df.loc[index, 'car_plate_number']]['Status_has_changed'])
        ind = index_list.index(index)
        while not bool_list[ind] and ind < len(index_list):
            ind+=1 # Looking for the last segment for which the status has changed
        return df.loc[index_list[ind], feature_name]
    
def new_feature_cum(index, feature_name):
    # returns the sum of all values of the feature on the segments to interpolate
    if df.loc[index, 'Status_has_changed']:
        return df.loc[index, feature_name]
    else :
        value = int(df.loc[index, feature_name])
        index_list = list(df.loc[df['car_plate_number']==df.loc[index, 'car_plate_number']].index)
        bool_list = list(df.loc[df['car_plate_number']==df.loc[index, 'car_plate_number']]['Status_has_changed'])
        ind = index_list.index(index)
        while not bool_list[ind] and ind < len(index_list):
            ind+=1
            value += int(df.loc[index_list[ind], feature_name])
        return value

# %%
features_to_change = ['latitude', 'longitude']
features_to_cumulate = ['distance', 'delta_battery']

for name in features_to_change :
    df['new_'+name] = df.index.map(lambda x: new_feature(x, name))
    

for name in features_to_cumulate :
    df['new_'+name] = df.index.map(lambda x: new_feature_cum(x, name))

# %%
for name in features_to_change :
    df[name] = df['new_'+name]
    df.drop('new_'+name, axis=1, inplace=True)

for name in features_to_cumulate :
    df[name] = df['new_'+name]
    df.drop('new_'+name, axis=1, inplace=True)

# %%
# Delete lines
def to_keep(index):
    next_index = next_segment(index)
    if next_index == -1 or df.loc[next_index, 'Status_has_changed']:
        return True
    return False

# %%
df["to_keep"]=df.index.map(to_keep)
df
df = df[df["to_keep"]]
df.drop("to_keep", axis=1, inplace=True)
df.drop("Status_has_changed", axis=1, inplace=True)
# UNIT TEST : GB-102-JY (done!)

# %% [markdown]
# ## Start date column
#
# $startdate = endate - duration$

# %%
def start_date(index):
    time = df.loc[index, 'time_since_2020'] - df.loc[index, 'kibana_duration'] # Start time since 2020
    year = 2020 + time // (365*24*60)
    time = time % (365*24*60)
    i = 0
    while cum_durations[i]< (time // (24*60)) and i < 12:
        i+=1
    month = inv_month[i]
    day = time // (24*60) - cum_durations[i-1] if i else time // (24*60)
    time = time % (24*60)
    hour = time // 60
    minute = time % 60
    return year, month, day, hour, minute
  
    
df['year']=df.index.map(lambda x: start_date(x)[0])
df['month']=df.index.map(lambda x: start_date(x)[1])
df['day_number']=df.index.map(lambda x: start_date(x)[2])
df['hour']=df.index.map(lambda x: start_date(x)[3])
df['minute']=df.index.map(lambda x: start_date(x)[4])

# %%
df.drop(['end_year', 'end_month', 'end_day_number', 'time_since_2020'], axis=1, inplace=True)

# %% [markdown]
# ### Day of the week
# scripted_day_of_week contains many nans, so we recalculate the day of week with the datetime module. Actually __scripted day of week__ is mostly wrong as there are 23,191 entries with __scripted day of week__ $\neq$ __day of week__.

# %%
def get_week_day(index):
    day = df.loc[index, 'day_number']
    month = monthdict[df.loc[index, 'month']]+1
    year = df.loc[index, 'year']
    if day==0:
        # Bug: 179 entries with date 2021-01-0, scripted_day_of_week was indicating 3 in isoweekday
        return 2
    return datetime.date(year, month, day).weekday()

df['day_of_week']=df.index.map(get_week_day)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79714 entries, 0 to 115976
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_plate_number  79714 non-null  object
#  1   status            79714 non-null  object
#  2   group_id          79714 non-null  object
#  3   kibana_duration   79714 non-null  int64
#  4   distance          79714 non-null  float64
#  5   zipcode           79714 non-null  int64
#  6   delta_battery     79713 non-null  float64
#  7   latitude          79714 non-null  float64
#  8   longitude         79714 non-null  float64
#  9   end_hour          79714 non-null  int64
#  10  end_minutes       79714 non-null  int64
#  11  duration          79714 non-null  int64
#  12  year              79714 non-null  int64
#  13  month             79714 non-null  object
#  14  day_number        79714 non-null  int64
#  15  hour              79714 non-null  int64
#  16  minute            79714 non-null  int64
#  17  day_of_week       79714 non-null  int64
# dtypes: float64(4), int64(10), object(4)
# memory usage: 13.6+ MB

# %% [markdown]
# ## Export csv

# %%
df.to_csv("75015.csv")

# %% [markdown]
# df.info()

# %% [markdown]
# ### Compare durations

# %%
print((df["kibana_duration"]-df["duration"]).describe())
print(len(df[abs(df["kibana_duration"]-df["duration"])>1]))
# Out:
# count     79108.000000
# mean      -2104.852619
# std        7883.341602
# min     -211148.000000
# 25%         -73.000000
# 50%           0.000000
# 75%           0.000000
# max       70377.000000
# dtype: float64
# 24245

# %%
print(df['duration'].describe())
print(df['kibana_duration'].describe())
# Out:
# count     79108.000000
# mean       2319.927479
# std        8049.247828
# min           0.000000
# 25%          10.000000
# 50%          35.000000
# 75%         715.000000
# max      211289.000000
# Name: duration, dtype: float64
# count     79108.000000
# mean        215.074860
# std        1894.580198
# min           0.000000
# 25%           9.000000
# 50%          21.000000
# 75%          96.000000
# max      154397.000000
# Name: kibana_duration, dtype: float64

# %%
df2 = df[df['kibana_duration']<3000]

# %%
print(df2['duration'].describe())
print(df2['kibana_duration'].describe())
# Out:
# count     78691.000000
# mean       2263.086960
# std        7841.666596
# min           0.000000
# 25%          10.000000
# 50%          34.000000
# 75%         676.000000
# max      211289.000000
# Name: duration, dtype: float64
# count    78691.000000
# mean       161.281252
# std        369.997596
# min          0.000000
# 25%          9.000000
# 50%         21.000000
# 75%         94.000000
# max       2996.000000
# Name: kibana_duration, dtype: float64

# %%
print((df2["kibana_duration"]-df2["duration"]).describe())
print(len(df2[abs(df2["kibana_duration"]-df2["duration"])>5]))
# Out:
# count     78691.000000
# mean      -2101.805708
# std        7802.988566
# min     -211148.000000
# 25%         -71.000000
# 50%           0.000000
# 75%           0.000000
# max        2905.000000
# dtype: float64
# 2159

# %%
df3=df2[abs(df2["kibana_duration"]-df2["duration"])>5]
df2["difference"]=df2["kibana_duration"]-df2["duration"]
df3["difference"]=df3["kibana_duration"]-df3["duration"]
# Out:
# <ipython-input-301-d489ed1f8e07>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["difference"]=df2["kibana_duration"]-df2["duration"]
# <ipython-input-301-d489ed1f8e07>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["difference"]=df3["kibana_duration"]-df3["duration"]

# %%
df2.groupby(by=['year', 'month'])["difference"].mean()
# Out:
# year  month
# 2020  Dec      -3932.295925
#       Nov      -4364.131498
# 2021  Apr      -1576.518218
#       Aug      -1647.472214
#       Dec      -1980.908713
#       Feb      -1781.128933
#       Jan      -4210.909416
#       Jul      -1339.882976
#       Jun      -1222.672934
#       Mar      -2306.742976
#       May      -1373.527765
#       Nov      -1880.541496
#       Oct      -2074.633855
#       Sep      -1627.188889
# 2022  Apr     -38155.285714
#       Feb      -5906.954279
#       Jan      -3938.447429
#       Mar     -10609.586552
#       May       -319.746114
# Name: difference, dtype: float64
