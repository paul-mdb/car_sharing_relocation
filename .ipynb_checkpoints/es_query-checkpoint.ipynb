# %%
from elasticsearch import Elasticsearch
from ssl import create_default_context

es = Elasticsearch("https://elastic:cLAZZSf96XI5AR247XYDl9W5@efa8ba28126d463b873bf67c74f49e0f.eu-west-1.aws.found.io:9243")

es.info()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedProductError                   Traceback (most recent call last)
# <ipython-input-3-0fe1da18f7ca> in <module>
#       4 es = Elasticsearch("https://elastic:cLAZZSf96XI5AR247XYDl9W5@efa8ba28126d463b873bf67c74f49e0f.eu-west-1.aws.found.io:9243")
#       5
# ----> 6 es.info()
#       7
#
# ~/opt/anaconda3/lib/python3.8/site-packages/elasticsearch/_sync/client/utils.py in wrapped(*args, **kwargs)
#     412                         pass
#     413
# --> 414             return api(*args, **kwargs)
#     415
#     416         return wrapped  # type: ignore[return-value]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/elasticsearch/_sync/client/__init__.py in info(self, error_trace, filter_path, human, pretty)
#    2275             __query["pretty"] = pretty
#    2276         __headers = {"accept": "application/json"}
# -> 2277         return self.perform_request(  # type: ignore[return-value]
# ...

# %%
latitude_upper_left = 48.86052264380334
latitude_lower_right = 48.79179783064239
longitude_upper_left = 2.251532213767741
longitude_lower_right = 2.4093229912176493

number_of_line = 4
number_of_colomn = 5
latitude_segment = (latitude_upper_left - latitude_lower_right) / number_of_line 
longitude_segment = (longitude_lower_right - longitude_upper_left) / number_of_colomn
latitude_list = []
longitude_list = []
for i in range(0,number_of_line+1):
    a = latitude_upper_left - i*latitude_segment
    latitude_list.append(a)

for i in range(0,number_of_colomn+1):
    a = longitude_upper_left + i*longitude_segment
    longitude_list.append(a)

([lo1,la1],[lo2,lo2]) ([lo2,la1],[lo3,la2])
# Out:
# [48.86052264380334,
#  48.8433414405131,
#  48.826160237222865,
#  48.80897903393263,
#  48.79179783064239]

# %%
result = es.search(
    index="carshare_car_history",
    body = {
  "query": {
    "bool": {
      "must": {
        "match_all": {}
      },
      "filter": [
        {"geo_shape": {
          "location": {
            "shape": {
              "type": "envelope",
              "coordinates": [ [ 2.2454, 48.82711 ], [ 2.24596, 48.82672 ] ]
            },
            "relation": "intersects"
          }
        }
      },
      {"range": { 
        "last_update": {
          "gte": 0,
          "lte": 1752186853000
        }
      }},
      {"script": { 
        "script": {"source": """
        doc['last_update'].value.getHour() >= 11 && doc['last_update'].value.getHour() <= 19 && doc['last_update'].value.getDayOfWeekEnum().getValue() >=1
        """
        }
      }}]
    }
  },
  "aggs": {
    "avg_Freeduration": {
      "avg": {
        "field": "duration"
      }
    }
  ,"car_count":{
    "value_count": {
      "field": "duration"
    }
  }}
}
 
)
result
# Out:
# {'took': 28,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 171, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'carshare_car_history',
#     '_type': '_doc',
#     '_id': '170baad5-6f18-11ec-8b90-000d3a89d198',
#     '_score': 1.0,
#     '_source': {'distance': 0,
#      'address': '17 Rue Jules Ferry, 92100 Boulogne-Billancourt, France',
#      'time_since_last_free': None,
#      'end_zipcode': None,
#      'city': 'Paris',
#      'start_charging_date': None,
#      'table_name': 'carshare_car_history',
#      'previous_booking_id': None,
#      'group_id': 'Zity Corporate',
#      'end_location': None,
#      'time_since_last_charge': 0,
#      'time_since_last_movement': 0,
#      '@timestamp': '2022-01-06T23:28:43.936Z',
#      'brand': 'Zity',
#      'end_address': None,
#      'duration': 0,
#      'mileage': 0,
#      'end__date': '1752-12-31T23:50:39.000Z',
# ...
