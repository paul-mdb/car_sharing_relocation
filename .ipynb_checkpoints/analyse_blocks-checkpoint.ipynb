# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt

df = pd.read_csv("segments_v1.csv")

# %%
df
# Out:
#        Unnamed: 0         status  distance car_plate_number  scripted_hour  \
# 0               0         BOOKED     171.0        GB-885-JX             15
# 1               1           FREE       0.0        FZ-189-RF             14
# 2               2         BOOKED     230.0        FZ-174-RF             14
# 3               3           FREE       0.0        FB-227-YK             12
# 4               4  BOOKED_PARKED      55.0        GB-839-JX             11
# ...           ...            ...       ...              ...            ...
# 50830       84951  BOOKED_PARKED       9.0        GB-992-JX             17
# 50831       84952         BOOKED       1.0        GB-095-JY             17
# 50832       84953           FREE       3.0        GB-971-JX             17
# 50833       84954         BOOKED       9.0        GB-942-JX             17
# 50834       84955           FREE       1.0        GB-864-JX             17
#
#        scripted_day_of_week   latitude  longitude       end_time  end_year  \
# 0                         4  48.841747   2.329786   15:10:25.225      2022
# 1                         4  48.831562   2.232407   14:22:15.834      2022
# 2                         4  48.873096   2.396167   14:06:58.957      2022
# 3                         4  48.820107   2.279744   12:41:14.950      2022
# 4                         4  48.846836   2.283492   11:38:06.372      2022
# ...                     ...        ...        ...            ...       ...
# 50830                     1  48.852340   2.205240   15:53:26.627      2022
# 50831                     1  48.846440   2.343130   15:53:22.220      2022
# 50832                     1  48.846330   2.400280   15:53:26.140      2022
# 50833                     1  48.840230   2.374340   15:53:25.637      2022
# 50834                     1  48.867830   2.405080   15:53:23.917      2022
#
#        delta_battery end_month  end_day_number  time_since_2020  duration  \
# 0                 -4       Jun               2          1272430     34270
# 1                 -1       Jun               2          1272382       911
# 2                -31       Jun               2          1272366     39846
# 3                 -1       Jun               2          1272281     34777
# 4                -25       Jun               2          1272218     54761
# ...              ...       ...             ...              ...       ...
# 50830             -8       Jan               3          1056473         0
# 50831             -1       Jan               3          1056473         0
# 50832              0       Jan               3          1056473         0
# 50833             -8       Jan               3          1056473         0
# 50834             -1       Jan               3          1056473         0
#
#        zipcode
# 0        75005
# 1        75005
# 2        75005
# 3        75005
# 4        75005
# ...        ...
# 50830    75005
# 50831    75005
# 50832    75005
# 50833    75005
# 50834    75005
#
# [50835 rows x 16 columns]

# %%
-28%60
# Out:
# 32

# %%
# df['zipcode']=75005

# %%
def geo_block(dataframe, district):
    return dataframe[dataframe['zipcode']==district]

def time_block(dataframe, start_time, end_time, scripted_day):
    return dataframe.loc[(dataframe['scripted_hour']>= start_time) & (dataframe['scripted_hour']<= end_time) & (dataframe['scripted_day_of_week']==scripted_day)]

# %%
time_blocks = [(0, 5), (6, 9), (10, 11), (12, 13), (14, 15), (16, 18), (19, 23)] # obtained from the daily num
geo_blocks = df['zipcode'].unique()
days = np.sort(df['scripted_day_of_week'].unique())
days_dict = {1: "Monday", 2:"Tuesday", 3:"Wednesday", 4:"Thursday", 5:"Friday", 6: "Saturday", 7: "Sunday"}
# Out:
# Monday

# %%
def free_duration_max(dataframe, district, start_date, end_date, day):
    dataframe = geo_block(dataframe, district)
    dataframe = time_block(dataframe, start_date, end_date, day)
    return dataframe.loc[dataframe['status']=='FREE']['duration'].max()

# %%
def free_duration_min(dataframe, district, start_date, end_date, day):
    dataframe = geo_block(dataframe, district)
    dataframe = time_block(dataframe, start_date, end_date, day)
    return dataframe.loc[dataframe['status']=='FREE']['duration'].min()

# %%
def free_duration_mean(dataframe, district, start_date, end_date, day):
    dataframe = geo_block(dataframe, district)
    dataframe = time_block(dataframe, start_date, end_date, day)
    return dataframe.loc[dataframe['status']=='FREE']['duration'].mean()

# %%
def free_duration_std(dataframe, district, start_date, end_date, day):
    dataframe = geo_block(dataframe, district)
    dataframe = time_block(dataframe, start_date, end_date, day)
    return dataframe.loc[dataframe['status']=='FREE']['duration'].std()

# %%
## BUG : Compte sur tous les mêmes blocs confondus, il faut que la date soit la même

def total_booked_cars(dataframe, district, start_date, end_date, day):
    dataframe = geo_block(dataframe, district)
    dataframe = time_block(dataframe, start_date, end_date, day)
    return len(dataframe.loc[dataframe['status']!='FREE'])

# %%
## Same BUG

def total_free_cars(dataframe, district, start_date, end_date, day):
    dataframe = geo_block(dataframe, district)
    dataframe = time_block(dataframe, start_date, end_date, day)
    return len(dataframe.loc[dataframe['status']=='FREE'])

# %%
features = [total_free_cars, total_booked_cars, free_duration_std, free_duration_mean, free_duration_max, free_duration_min]
feature_names = ['total free cars', 'total booked cars', 'free duration standard deviation', 'free duration mean', 'max free duration', 'min free duration']

# %%
# Calculating features and storing results in a dedicated dataframe
array = np.empty(shape=(0, 4+len(features)))
for day, (start_date, end_date), district in itertools.product(days, time_blocks, geo_blocks):
    row = [district, day, start_date, end_date]
    for feature in features :
        row.append(feature(df, district, start_date, end_date, day))
    array = np.vstack([array, row])

results = pd.DataFrame(array, columns = ['district', 'day', 'start hour', 'end hour']+feature_names)
results = results.astype(int)
results = results.replace({'day': days_dict})

# %%
results.head()
# Out:
#    district     day  start hour  end hour  total free cars  total booked cars  \
# 0     75005  Monday           0         5              160                368
# 1     75005  Monday           6         9              235                342
# 2     75005  Monday          10        11              177                296
# 3     75005  Monday          12        13              143                393
# 4     75005  Monday          14        15              142                262
#
#    free duration standard deviation  free duration mean  max free duration  \
# 0                               870                 380               9458
# 1                               907                 800               6880
# 2                              2371                 804              29503
# 3                               873                 631               4393
# 4                              1264                 699              10553
#
#    min free duration
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                 19

# %%
df.head()
# Out:
#    Unnamed: 0         status  distance car_plate_number  scripted_hour  \
# 0           0         BOOKED     171.0        GB-885-JX             15
# 1           1           FREE       0.0        FZ-189-RF             14
# 2           2         BOOKED     230.0        FZ-174-RF             14
# 3           3           FREE       0.0        FB-227-YK             12
# 4           4  BOOKED_PARKED      55.0        GB-839-JX             11
#
#    scripted_day_of_week   latitude  longitude       end_time  end_year  \
# 0                     4  48.841747   2.329786   15:10:25.225      2022
# 1                     4  48.831562   2.232407   14:22:15.834      2022
# 2                     4  48.873096   2.396167   14:06:58.957      2022
# 3                     4  48.820107   2.279744   12:41:14.950      2022
# 4                     4  48.846836   2.283492   11:38:06.372      2022
#
#    delta_battery end_month  end_day_number  time_since_2020  duration  zipcode
# 0             -4       Jun               2          1272430     34270    75005
# 1             -1       Jun               2          1272382       911    75005
# 2            -31       Jun               2          1272366     39846    75005
# 3             -1       Jun               2          1272281     34777    75005
# 4            -25       Jun               2          1272218     54761    75005

# %%
district = 75005
start_date = 0
end_date = 23
day = 1
dataframe = geo_block(df, district)
dataframe = time_block(dataframe, start_date, end_date, day).loc[dataframe["status"]=="FREE"]
durations_means = dataframe.groupby(by=['end_month', 'end_day_number'])['duration'].mean().values
count = dataframe.groupby(by=['end_month', 'end_day_number'])['duration'].count().values
plt.figure(figsize=(15, 6))
plt.scatter(count, durations_means)
plt.xlabel("Number of free cars in block")
plt.ylabel("free duration mean")
plt.ylim(0, 1500)
plt.show()

# %% [markdown]
# Use DBSCAN to get clusters ?
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html
# demand_estimation.pdf page 6

# %% [markdown]
# Filtrer sur une poignées de plaques sur kibana pour vérifier les calculs de duration. Puis plotter les corrélations en filtrant les arrondissements.

# %%
print(results['total booked cars'].sum())
print(results['total free cars'].sum())
# Out:
# 34620
# 16215
